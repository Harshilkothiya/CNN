# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshilkothiya/CNN/blob/main/51_DL_Pretrained_models_in_CNN_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
img_path = 'laptop.webp'
img = image.load_img(img_path, target_size = (224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x
# Out:
# array([[[213., 188., 158.],
#         [210., 190., 158.],
#         [211., 189., 158.],
#         ...,
#         [203., 174., 145.],
#         [203., 174., 145.],
#         [202., 175., 145.]],
#
#        [[213., 188., 158.],
#         [211., 189., 158.],
#         [211., 189., 158.],
#         ...,
#         [203., 174., 145.],
#         [203., 174., 145.],
#         [202., 175., 145.]],
#
#        [[211., 189., 158.],
#         [213., 188., 158.],
#         [211., 189., 158.],
#         ...,
#         [204., 175., 146.],
#         [203., 174., 145.],
#         [202., 175., 145.]],
#
#        ...,
#
#        [[231., 212., 189.],
#         [231., 215., 188.],
#         [230., 214., 187.],
#         ...,
#         [226., 203., 179.],
#         [228., 204., 180.],
#         [226., 203., 179.]],
#
#        [[231., 213., 187.],
#         [231., 215., 188.],
#         [231., 215., 188.],
#         ...,
#         [226., 203., 179.],
#         [226., 203., 179.],
# ...

# %%
x = np.expand_dims(x, axis =0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
print('Predicted:', decode_predictions(preds, top=10)[0])
# Out:
# Predicted: [('n03832673', 'notebook', 0.82005817), ('n06359193', 'web_site', 0.0686047), ('n03642806', 'laptop', 0.041452225), ('n03085013', 'computer_keyboard', 0.021936163), ('n01968897', 'chambered_nautilus', 0.01826623), ('n03180011', 'desktop_computer', 0.0037860873), ('n04522168', 'vase', 0.002909959), ('n04152593', 'screen', 0.0024700952), ('n03782006', 'monitor', 0.0023306995), ('n07930864', 'cup', 0.0021278267)]

# %%
x = np.array([[1, 2, 3], [4, 5, 6]])
print(x)  # Output: (2, 3)

x_expanded = np.expand_dims(x, axis=0)
print(x_expanded)  # Output: (1, 2, 3)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[[1 2 3]
#   [4 5 6]]]
